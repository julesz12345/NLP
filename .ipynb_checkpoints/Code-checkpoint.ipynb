# %% [markdown]
# **<font size = 6> Creating a Chatbot using NLP**

# %% [markdown]
# <font size = 4> Creating the dataset that will be used to train the model

# %%
data = {"intents": [
             {"tag": "greeting",
              "patterns": ["Hello", "How are you", "Hi there", "Hi", "Whats up"],
              "responses": ["Howdy Partner!", "Hello", "How are you doing?", "Greetings!", "How do you do?"],
             },
             {"tag": "age",
              "patterns": ["how old are you?", "when is your birthday?", "when was you born?"],
              "responses": ["I am 24 years old", "I was born in 1996", "My birthday is July 3rd and I was born in 1996", "03/07/1996"]
             },
             {"tag": "date",
              "patterns": ["what are you doing this weekend?",
"do you want to hang out some time?", "what are your plans for this week"],
              "responses": ["I am available all week", "I don't have any plans", "I am not busy"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "what are you called?", "who are you?"],
              "responses": ["My name is Kippi", "I'm Kippi", "Kippi"]
             },
             {"tag": "goodbye",
              "patterns": [ "bye", "g2g", "see ya", "adios", "cya"],
              "responses": ["It was nice speaking to you", "See you later", "Speak soon!"]
             }
]}

# %% [markdown]
# <font size = 4> Importing Packages

# %%
import json
import string
import random 
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jules\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Jules\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# <font size = 4> Processing and Cleaning Data

# %%
# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()
# Each list to create
words = []
classes = []
doc_X = []
doc_y = []
# Loop through all the intents
# tokenize each pattern and append tokens to words, the patterns and
# the associated tag to their associated list
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_X.append(pattern)
        doc_y.append(intent["tag"])
    
    # add the tag to the classes if it's not there already 
    if intent["tag"] not in classes:
        classes.append(intent["tag"])
# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %% [markdown]
# <font size = 4> Building Variables

# %%
# list for training data
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(doc_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(doc_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training 
    training.append([bow, output_row])
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[:, 0]))
train_y = np.array(list(training[:, 1]))

# %% [markdown]
# <font size = 4> Training Model

# %%
# defining some parameters
input_shape = (len(train_X[0]),)
output_shape = len(train_y[0])
epochs = 200
# the deep learning model
model = Sequential()
model.add(Dense(128, input_shape=input_shape, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(output_shape, activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_y, epochs=200, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               5120
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 13,701
# Trainable params: 13,701
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7267 - accuracy: 0.0526
# Epoch 2/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5803 - accuracy: 0.2632
# Epoch 3/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4418 - accuracy: 0.5789
# Epoch 4/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3115 - accuracy: 0.7368
# Epoch 5/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1809 - accuracy: 0.8947
# Epoch 6/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1709 - accuracy: 0.8421
# Epoch 7/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8877 - accuracy: 1.0000
# Epoch 8/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8191 - accuracy: 1.0000
# Epoch 9/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6484 - accuracy: 0.8947
# Epoch 10/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6700 - accuracy: 0.9474
# Epoch 11/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5748 - accuracy: 0.8421
# Epoch 12/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5014 - accuracy: 0.7368
# Epoch 13/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3065 - accuracy: 0.9474
# Epoch 14/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2590 - accuracy: 0.9474
# Epoch 15/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1357 - accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2052 - accuracy: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0599 - accuracy: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1553 - accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1209 - accuracy: 0.9474
# Epoch 21/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0702 - accuracy: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0561 - accuracy: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0951 - accuracy: 0.9474
# Epoch 24/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0738 - accuracy: 0.9474
# Epoch 28/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0365 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2124 - accuracy: 0.9474
# Epoch 32/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1150 - accuracy: 0.9474
# Epoch 33/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0945 - accuracy: 0.9474
# Epoch 36/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1047 - accuracy: 0.9474
# Epoch 42/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0582 - accuracy: 0.9474
# Epoch 46/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9919e-04 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0461e-04 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0482 - accuracy: 0.9474
# Epoch 53/200
# 1/1 [==============================] - 0s 5ms/step - loss: 8.7776e-04 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 5ms/step - loss: 8.1519e-04 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9866e-05 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0413e-04 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 5ms/step - loss: 5.8808e-04 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 1.00 - 0s 7ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 4ms/step - loss: 5.3977e-04 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3658e-04 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 6ms/step - loss: 3.5901e-04 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.2407e-04 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7766e-04 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.00 - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 5ms/step - loss: 8.5830e-04 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1187 - accuracy: 0.9474
# Epoch 89/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0818e-04 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.4123e-04 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 4ms/step - loss: 2.6659e-04 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 996us/step - loss: 8.3550e-04 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 998us/step - loss: 2.6139e-04 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.8890e-04 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.0934e-04 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 997us/step - loss: 4.0413e-04 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.3051e-04 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3940e-04 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6941e-04 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 3ms/step - loss: 9.4778e-05 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 3ms/step - loss: 5.3073e-04 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.5681e-04 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 5ms/step - loss: 9.5795e-04 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3280e-04 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 3ms/step - loss: 6.8503e-04 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.4366e-05 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2266e-05 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0428e-04 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 5ms/step - loss: 3.6378e-05 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5790e-04 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7396e-04 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3062e-04 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 3ms/step - loss: 5.2396e-04 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.0398e-04 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 4ms/step - loss: 4.3918e-04 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5469e-04 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2324e-04 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6113e-04 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 3ms/step - loss: 6.1473e-04 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6252e-04 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 998us/step - loss: 9.3193e-04 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 997us/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.4047e-04 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5518e-04 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 3ms/step - loss: 6.2582e-05 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 6ms/step - loss: 3.8546e-04 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.4196e-04 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.2127e-04 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 997us/step - loss: 1.2770e-04 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 5ms/step - loss: 4.1270e-04 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.6541e-05 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1870e-04 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0359e-04 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0210e-04 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.8438e-04 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2179e-04 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2328e-05 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2256e-04 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.2047e-04 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3840e-04 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2837e-04 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4630e-05 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2573e-05 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 4ms/step - loss: 4.5012e-05 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4049e-04 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7177e-05 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9780e-04 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 1000us/step - loss: 2.9245e-04 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.1432e-04 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5300e-04 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7580e-04 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 2ms/step - loss: 9.1492e-04 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4951e-05 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 4ms/step - loss: 3.2766e-05 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 998us/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9349e-04 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3427e-05 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6606e-04 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.7940e-05 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2895e-04 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - ETA: 0s - loss: 8.8825e-05 - accuracy: 1.00 - 0s 4ms/step - loss: 8.8825e-05 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6038e-04 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9385e-05 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2541e-05 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.9223e-05 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0211e-04 - accuracy: 1.0000

# %% [markdown]
# <font size = 4> Chatbot Actions

# %%
def clean_text(text): 
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab): 
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens: 
    for idx, word in enumerate(vocab):
      if word == w: 
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels): 
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.2
  y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]

  y_pred.sort(key=lambda x: x[1], reverse=True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
  return return_list

def get_response(intents_list, intents_json): 
  tag = intents_list[0]
  list_of_intents = intents_json["intents"]
  for i in list_of_intents: 
    if i["tag"] == tag:
      result = random.choice(i["responses"])
      break
  return result

# %% [markdown]
# <font size = 4> Running Chatbot

# %%
# running the chatbot
temp = 0
while temp == 0:
    message = input("")
    if message == "off":
        temp = 1
    else:
        intents = pred_class(message, words, classes)
        result = get_response(intents, data)
        print(result)
# Out:
# hello
# How do you do?
# how old are you
# 03/07/1996
# goodbye
# It was nice speaking to you
# off
