# %%
data = {"intents": [
             {"tag": "greeting",
              "patterns": ["Hello", "How are you?", "Hi there", "Hi", "Whats up"],
              "responses": ["Howdy Partner!", "Hello", "How are you doing?", "Greetings!", "How do you do?"],
             },
             {"tag": "age",
              "patterns": ["how old are you?", "when is your birthday?", "when was you born?"],
              "responses": ["I am 24 years old", "I was born in 1996", "My birthday is July 3rd and I was born in 1996", "03/07/1996"]
             },
             {"tag": "date",
              "patterns": ["what are you doing this weekend?",
"do you want to hang out some time?", "what are your plans for this week"],
              "responses": ["I am available all week", "I don't have any plans", "I am not busy"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "what are you called?", "who are you?"],
              "responses": ["My name is Kippi", "I'm Kippi", "Kippi"]
             },
             {"tag": "goodbye",
              "patterns": [ "bye", "g2g", "see ya", "adios", "cya"],
              "responses": ["It was nice speaking to you", "See you later", "Speak soon!"]
             }
]}

# %%
import json
import string
import random 
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jules\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Jules\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()
# Each list to create
words = []
classes = []
doc_X = []
doc_y = []
# Loop through all the intents
# tokenize each pattern and append tokens to words, the patterns and
# the associated tag to their associated list
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_X.append(pattern)
        doc_y.append(intent["tag"])
    
    # add the tag to the classes if it's not there already 
    if intent["tag"] not in classes:
        classes.append(intent["tag"])
# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %%
# list for training data
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(doc_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(doc_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training 
    training.append([bow, output_row])
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[:, 0]))
train_y = np.array(list(training[:, 1]))

# %%
# defining some parameters
input_shape = (len(train_X[0]),)
output_shape = len(train_y[0])
epochs = 200
# the deep learning model
model = Sequential()
model.add(Dense(128, input_shape=input_shape, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(output_shape, activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_y, epochs=200, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               5120
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 13,701
# Trainable params: 13,701
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.7899 - accuracy: 0.0000e+00
# Epoch 2/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.5311 - accuracy: 0.5789
# Epoch 3/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.4455 - accuracy: 0.4211
# Epoch 4/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.3934 - accuracy: 0.6316
# Epoch 5/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.3060 - accuracy: 0.5789
# Epoch 6/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.1659 - accuracy: 0.6842
# Epoch 7/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.0588 - accuracy: 0.6842
# Epoch 8/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.9817 - accuracy: 0.7368
# Epoch 9/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.7049 - accuracy: 0.9474
# Epoch 10/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.7413 - accuracy: 0.8421
# Epoch 11/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4803 - accuracy: 0.9474
# Epoch 12/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.4953 - accuracy: 0.8421
# Epoch 13/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4398 - accuracy: 0.8421
# Epoch 14/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5066 - accuracy: 0.7895
# Epoch 15/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.5018 - accuracy: 0.7895
# Epoch 16/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3060 - accuracy: 0.8947
# Epoch 17/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.2843 - accuracy: 0.9474
# Epoch 18/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.2608 - accuracy: 0.8947
# Epoch 19/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.1100 - accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.2028 - accuracy: 0.8947
# Epoch 21/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.1815 - accuracy: 0.8947
# Epoch 22/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0832 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0810 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0912 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0978 - accuracy: 0.9474
# Epoch 27/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0813 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0649 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0516 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0868 - accuracy: 0.9474
# Epoch 32/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.1325 - accuracy: 0.9474
# Epoch 35/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 1.00 - 0s 0s/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0616 - accuracy: 0.9474
# Epoch 41/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0597 - accuracy: 0.9474
# Epoch 50/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0992 - accuracy: 0.9474
# Epoch 59/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.3490e-04 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.8026e-04 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.8844e-04 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 0s/step - loss: 9.7098e-04 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.9890e-04 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.6783e-04 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 0s/step - loss: 8.0381e-04 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 0s/step - loss: 9.6795e-04 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.4298e-04 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.1852e-04 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.9024e-04 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5299e-04 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8290e-04 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.2905e-04 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.5233e-05 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.2068e-04 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.5331e-04 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.3776e-04 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 0s/step - loss: 8.9908e-04 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.9576e-04 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.4030e-04 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.4331e-05 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.3583e-04 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.5485e-04 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.5118e-04 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.3668e-04 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 0s/step - loss: 6.6534e-05 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 0s/step - loss: 6.0264e-04 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.4034e-04 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0500 - accuracy: 0.9474
# Epoch 117/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.1994e-04 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.7851e-04 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0510 - accuracy: 0.9474
# Epoch 121/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.7174e-04 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 0s/step - loss: 8.6216e-04 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.2448e-04 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.5131e-05 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.5059e-04 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7275e-04 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.9267e-05 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.7732e-05 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0520 - accuracy: 0.9474
# Epoch 138/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.0853e-04 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.3852e-04 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 0s/step - loss: 6.1804e-04 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.0469e-04 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.0991e-04 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.2914e-04 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0916 - accuracy: 0.9474
# Epoch 151/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.6312e-05 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.6052e-06 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.9574e-04 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.4426e-04 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.9655e-05 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.9452e-04 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 0s/step - loss: 8.2457e-05 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.2170e-04 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0886 - accuracy: 0.9474
# Epoch 164/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.0609e-05 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.2552e-04 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.1023e-04 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.6451e-05 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.4372e-04 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.9531e-04 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.5107e-04 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.1542e-04 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.7358e-04 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4285e-04 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 0s/step - loss: 8.4721e-04 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4348e-05 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.6367e-05 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.5508e-04 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.5571e-04 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.2277e-04 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.1964e-05 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.4474e-05 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0134e-04 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2487e-04 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.7686e-04 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.5341e-04 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.8066e-04 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.9163e-05 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.3741e-05 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.7458e-04 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 0s/step - loss: 9.8686e-06 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.7496e-05 - accuracy: 1.0000

# %%
def clean_text(text): 
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab): 
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens: 
    for idx, word in enumerate(vocab):
      if word == w: 
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels): 
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.2
  y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]

  y_pred.sort(key=lambda x: x[1], reverse=True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
  return return_list

def get_response(intents_list, intents_json): 
  tag = intents_list[0]
  list_of_intents = intents_json["intents"]
  for i in list_of_intents: 
    if i["tag"] == tag:
      result = random.choice(i["responses"])
      break
  return result

# %%
# running the chatbot
while True:
    message = input("")
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
