# %% [markdown]
# **<font size = 6> Creating a Chatbot using NLP**

# %%
data = {"intents": [
             {"tag": "greeting",
              "patterns": ["Hello", "How are you?", "Hi there", "Hi", "Whats up"],
              "responses": ["Howdy Partner!", "Hello", "How are you doing?", "Greetings!", "How do you do?"],
             },
             {"tag": "age",
              "patterns": ["how old are you?", "when is your birthday?", "when was you born?"],
              "responses": ["I am 24 years old", "I was born in 1996", "My birthday is July 3rd and I was born in 1996", "03/07/1996"]
             },
             {"tag": "date",
              "patterns": ["what are you doing this weekend?",
"do you want to hang out some time?", "what are your plans for this week"],
              "responses": ["I am available all week", "I don't have any plans", "I am not busy"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "what are you called?", "who are you?"],
              "responses": ["My name is Kippi", "I'm Kippi", "Kippi"]
             },
             {"tag": "goodbye",
              "patterns": [ "bye", "g2g", "see ya", "adios", "cya"],
              "responses": ["It was nice speaking to you", "See you later", "Speak soon!"]
             }
]}

# %%
import json
import string
import random 
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jules\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Jules\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()
# Each list to create
words = []
classes = []
doc_X = []
doc_y = []
# Loop through all the intents
# tokenize each pattern and append tokens to words, the patterns and
# the associated tag to their associated list
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_X.append(pattern)
        doc_y.append(intent["tag"])
    
    # add the tag to the classes if it's not there already 
    if intent["tag"] not in classes:
        classes.append(intent["tag"])
# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %%
# list for training data
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(doc_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(doc_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training 
    training.append([bow, output_row])
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[:, 0]))
train_y = np.array(list(training[:, 1]))

# %%
# defining some parameters
input_shape = (len(train_X[0]),)
output_shape = len(train_y[0])
epochs = 200
# the deep learning model
model = Sequential()
model.add(Dense(128, input_shape=input_shape, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(output_shape, activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_y, epochs=200, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               5120
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 13,701
# Trainable params: 13,701
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.6099 - accuracy: 0.2105
# Epoch 2/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.4814 - accuracy: 0.3684
# Epoch 3/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.3876 - accuracy: 0.5789
# Epoch 4/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.2956 - accuracy: 0.6842
# Epoch 5/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.1898 - accuracy: 0.7368
# Epoch 6/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.1005 - accuracy: 0.6842
# Epoch 7/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.9636 - accuracy: 0.7895
# Epoch 8/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.7541 - accuracy: 0.9474
# Epoch 9/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.8257 - accuracy: 0.7368
# Epoch 10/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.5570 - accuracy: 0.9474
# Epoch 11/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.4085 - accuracy: 0.9474
# Epoch 12/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3222 - accuracy: 1.0000
# Epoch 13/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3864 - accuracy: 0.9474
# Epoch 14/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.1756 - accuracy: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.2945 - accuracy: 0.9474
# Epoch 16/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.1665 - accuracy: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.1547 - accuracy: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.1729 - accuracy: 0.9474
# Epoch 19/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0962 - accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0957 - accuracy: 0.9474
# Epoch 21/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.1418 - accuracy: 0.9474
# Epoch 22/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0900 - accuracy: 0.9474
# Epoch 23/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0752 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0855 - accuracy: 0.9474
# Epoch 25/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.1408 - accuracy: 0.9474
# Epoch 26/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0666 - accuracy: 0.9474
# Epoch 32/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0847 - accuracy: 0.9474
# Epoch 38/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0821 - accuracy: 0.9474
# Epoch 48/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0759 - accuracy: 0.9474
# Epoch 51/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.9895e-04 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.9063e-04 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0500 - accuracy: 0.9474
# Epoch 60/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.0287e-04 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 0s/step - loss: 8.2755e-04 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 0s/step - loss: 9.7669e-05 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.9899e-04 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 0s/step - loss: 8.8126e-04 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 0s/step - loss: 6.3208e-05 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.2352e-05 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.4413e-04 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.9378e-04 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8731e-04 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.9997e-04 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3313e-04 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.7751e-04 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.2307e-04 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.1908e-04 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.9166e-04 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.5951e-04 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.8307e-04 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.0254e-05 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.5482e-04 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.2833e-04 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.4669e-04 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.5783e-04 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.1985e-04 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 0s/step - loss: 6.0286e-04 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.9656e-04 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.7547e-04 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.5345e-04 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 0s/step - loss: 9.9798e-04 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.5386e-04 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.1113e-04 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.8708e-05 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.3343e-05 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.6572e-04 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.2290e-04 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0233e-04 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.6836e-04 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 0s/step - loss: 6.8467e-05 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.3877e-04 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 0s/step - loss: 8.2571e-05 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.3081e-04 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.9139e-05 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.4388e-04 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5596e-04 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 0s/step - loss: 9.6059e-04 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.8999e-04 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2947e-04 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.7774e-04 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.1860e-05 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.4211e-04 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1312e-04 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.7297e-04 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.6909e-04 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.3025e-05 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.1805e-04 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.6103e-05 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.4194e-04 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.8180e-04 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.6008e-05 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.8317e-04 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.1739e-05 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.6864e-04 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7006e-04 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4523e-04 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.9262e-04 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 0s/step - loss: 6.2882e-04 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 0s/step - loss: 8.5278e-05 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 0s/step - loss: 9.1162e-06 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.6741e-05 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.2465e-06 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.4842e-04 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.4963e-04 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 0s/step - loss: 9.7966e-05 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.5052e-05 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.5515e-05 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.4672e-06 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.0071e-05 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.1185e-05 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 0s/step - loss: 6.4666e-05 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 0s/step - loss: 9.5054e-05 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.3551e-05 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.5596e-05 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.3125e-04 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.8677e-05 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.4005e-05 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4150e-04 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7624e-04 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.2152e-04 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 11ms/step - loss: 7.7503e-04 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.1603e-05 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.5628e-05 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.9690e-04 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7360e-04 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.7803e-04 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.6534e-04 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2845e-04 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.6842e-04 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.4614e-04 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.2307e-04 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.5580e-05 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7367e-05 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0171 - accuracy: 1.0000

# %%
def clean_text(text): 
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab): 
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens: 
    for idx, word in enumerate(vocab):
      if word == w: 
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels): 
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.2
  y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]

  y_pred.sort(key=lambda x: x[1], reverse=True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
  return return_list

def get_response(intents_list, intents_json): 
  tag = intents_list[0]
  list_of_intents = intents_json["intents"]
  for i in list_of_intents: 
    if i["tag"] == tag:
      result = random.choice(i["responses"])
      break
  return result

# %%
# running the chatbot
temp = 0
while temp == 0:
    message = input("")
    if message == "off":
        temp = 1
    else:
        intents = pred_class(message, words, classes)
        result = get_response(intents, data)
        print(result)
# Out:
# What is your name
# I was born in 1996
# What is your name^
# 03/07/1996
# off
