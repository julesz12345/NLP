# %% [markdown]
# **<font size = 6> Creating a Chatbot using NLP**

# %% [markdown]
# <font size = 4> Creating the dataset that will be used to train the model

# %%
data = {"intents": [
             {"tag": "greeting",
              "patterns": ["Hello", "How are you", "Hi there", "Hi", "Whats up"],
              "responses": ["Howdy Partner!", "Hello", "How are you doing?", "Greetings!", "How do you do?"],
             },
             {"tag": "age",
              "patterns": ["how old are you?", "when is your birthday?", "when was you born?"],
              "responses": ["I am 24 years old", "I was born in 1996", "My birthday is July 3rd and I was born in 1996", "03/07/1996"]
             },
             {"tag": "date",
              "patterns": ["what are you doing this weekend?",
"do you want to hang out some time?", "what are your plans for this week"],
              "responses": ["I am available all week", "I don't have any plans", "I am not busy"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "what are you called?", "who are you?"],
              "responses": ["My name is Kippi", "I'm Kippi", "Kippi"]
             },
             {"tag": "goodbye",
              "patterns": [ "bye", "g2g", "see ya", "adios", "cya"],
              "responses": ["It was nice speaking to you", "See you later", "Speak soon!"]
             }
]}

# %% [markdown]
# <font size = 4> Importing Packages

# %%
import json
import string
import random 
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jules\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Jules\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# <font size = 4> Processing and Cleaning Data

# %%
# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()
# Each list to create
words = []
classes = []
doc_X = []
doc_y = []
# Loop through all the intents
# tokenize each pattern and append tokens to words, the patterns and
# the associated tag to their associated list
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_X.append(pattern)
        doc_y.append(intent["tag"])
    
    # add the tag to the classes if it's not there already 
    if intent["tag"] not in classes:
        classes.append(intent["tag"])
# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %% [markdown]
# <font size = 4> Building Variables

# %%
# list for training data
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(doc_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(doc_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training 
    training.append([bow, output_row])
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[:, 0]))
train_y = np.array(list(training[:, 1]))

# %% [markdown]
# <font size = 4> Training Model

# %%
# defining some parameters
input_shape = (len(train_X[0]),)
output_shape = len(train_y[0])
epochs = 200
# the deep learning model
model = Sequential()
model.add(Dense(128, input_shape=input_shape, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(output_shape, activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_y, epochs=200, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               5120
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 13,701
# Trainable params: 13,701
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 1s 653ms/step - loss: 1.6955 - accuracy: 0.3158
# Epoch 2/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.5246 - accuracy: 0.4211
# Epoch 3/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3083 - accuracy: 0.6316
# Epoch 4/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.3073 - accuracy: 0.6316
# Epoch 5/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.1510 - accuracy: 0.7368
# Epoch 6/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0026 - accuracy: 0.8421
# Epoch 7/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9483 - accuracy: 0.7895
# Epoch 8/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7848 - accuracy: 0.9474
# Epoch 9/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6591 - accuracy: 0.8947
# Epoch 10/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6381 - accuracy: 0.8421
# Epoch 11/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5172 - accuracy: 0.8421
# Epoch 12/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4088 - accuracy: 0.8947
# Epoch 13/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3311 - accuracy: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2932 - accuracy: 0.8947
# Epoch 15/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2284 - accuracy: 0.8947
# Epoch 16/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1779 - accuracy: 0.9474
# Epoch 17/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2013 - accuracy: 0.9474
# Epoch 18/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0772 - accuracy: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0787 - accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0911 - accuracy: 0.9474
# Epoch 21/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.1210 - accuracy: 0.9474
# Epoch 22/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1033 - accuracy: 0.9474
# Epoch 23/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0597 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0471 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1674 - accuracy: 0.9474
# Epoch 27/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1174 - accuracy: 0.9474
# Epoch 30/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0818 - accuracy: 0.9474
# Epoch 37/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 47us/step - loss: 0.0467 - accuracy: 0.9474
# Epoch 48/200
# 1/1 [==============================] - 0s 10ms/step - loss: 6.8832e-04 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 10ms/step - loss: 6.3353e-04 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0442 - accuracy: 0.9474
# Epoch 60/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.7521e-04 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 10ms/step - loss: 7.0595e-04 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.0908e-04 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3551e-04 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4586e-04 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.2640e-05 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.1872e-04 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.2199e-04 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 5ms/step - loss: 8.4299e-04 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 10ms/step - loss: 6.6316e-04 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.6399e-04 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 13ms/step - loss: 8.7965e-04 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.3646e-04 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 9ms/step - loss: 6.9287e-04 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.1051e-04 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.8564e-04 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.4572e-04 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.9819e-04 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.5970e-05 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.6785e-04 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 5ms/step - loss: 6.7506e-04 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0997e-04 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5905e-04 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.3135e-04 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 10ms/step - loss: 9.6381e-05 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.7189e-05 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.4715e-04 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.4653e-04 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.2690e-04 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.1454 - accuracy: 0.9474
# Epoch 113/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 0s/step - loss: 9.8106e-05 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.4564e-04 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.6170e-04 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 5ms/step - loss: 5.4503e-04 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0478e-04 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 9ms/step - loss: 9.7464e-04 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.5490e-04 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0426 - accuracy: 0.9474
# Epoch 136/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.9127e-04 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 5ms/step - loss: 7.9052e-05 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 0s/step - loss: 6.7401e-04 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.8003e-04 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4932e-05 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 3ms/step - loss: 6.5747e-04 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2328e-05 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.7877e-04 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 5ms/step - loss: 6.2968e-05 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.7489e-04 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.3994e-05 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 5ms/step - loss: 3.7185e-04 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1015 - accuracy: 0.9474
# Epoch 155/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3600e-04 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7186e-04 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.7055e-04 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 10ms/step - loss: 7.9183e-05 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 10ms/step - loss: 8.2542e-05 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.5605e-04 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.5990e-05 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1510e-04 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 0s/step - loss: 8.1383e-04 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6141e-04 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0148e-04 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4535e-04 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0040e-04 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 5ms/step - loss: 3.4893e-05 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 0s/step - loss: 6.3083e-04 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2854e-04 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3752e-05 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.3906e-04 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 10ms/step - loss: 6.9902e-04 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.1899e-04 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.8217e-04 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.5700e-06 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.1244e-05 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.8187e-04 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.5127e-04 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 10ms/step - loss: 8.2825e-05 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.5007e-04 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.2726e-05 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 5ms/step - loss: 9.6597e-05 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.4482e-04 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 0s/step - loss: 5.9867e-05 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.7675e-04 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.4195e-04 - accuracy: 1.0000

# %% [markdown]
# <font size = 4> Chatbot Actions

# %%
def clean_text(text): 
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab): 
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens: 
    for idx, word in enumerate(vocab):
      if word == w: 
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels): 
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.2
  y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]

  y_pred.sort(key=lambda x: x[1], reverse=True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
  return return_list

def get_response(intents_list, intents_json): 
  tag = intents_list[0]
  list_of_intents = intents_json["intents"]
  for i in list_of_intents: 
    if i["tag"] == tag:
      result = random.choice(i["responses"])
      break
  return result

# %% [markdown]
# <font size = 4> Running Chatbot

# %%
# running the chatbot
temp = 0
while temp == 0:
    message = input("")
    if message == "off":
        temp = 1
    else:
        intents = pred_class(message, words, classes)
        result = get_response(intents, data)
        print(result)
# Out:
# off
